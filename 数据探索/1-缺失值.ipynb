# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_excel('../实验数据/股票财务数据.xlsx')

# %%
data
# Out:
#            证券代码   证券简称  净资产收益率/%  总资产报酬率/%   资产负债率/%      利息保障倍数  总资产周转率/次  \
# 0     000552.SZ   靖远煤电    4.0728    2.6888   33.8593     16.9084    0.3402
# 1     000571.SZ   新大洲A    2.5876    1.9879   40.8789      2.9765    0.1962
# 2     000780.SZ   平庄能源   -8.6950   -7.6697   24.1054         NaN    0.3613
# 3     000937.SZ   冀中能源    1.9159    1.9394   50.9582      1.1817    0.3042
# 4     000968.SZ  *ST煤气 -152.9181  -10.9300   94.1144     -2.9858    0.1185
# 5     000983.SZ   西山煤电    0.8843    2.7728   63.6522      1.2876    0.3716
# 6     002128.SZ   露天煤业    6.2041    5.9514   36.9467      4.2583    0.3988
# 7     600121.SH   郑州煤电  -14.2157   -2.3910   59.9710     -1.2192    1.0681
# 8     600123.SH   兰花科创    0.1434    0.6748   53.9731      0.8869    0.2077
# 9     600157.SH   永泰能源    3.9634    5.1374   70.3247      1.5645    0.1544
# 10    600188.SH   兖州煤业    2.1758    2.3733   69.0781      1.8910    0.5108
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3031 entries, 0 to 3030
# Data columns (total 10 columns):
# 证券代码           3031 non-null object
# 证券简称           3031 non-null object
# 净资产收益率/%       3013 non-null float64
# 总资产报酬率/%       2978 non-null float64
# 资产负债率/%        3028 non-null float64
# 利息保障倍数         2128 non-null float64
# 总资产周转率/次       3027 non-null float64
# 应收账款周转率/次      2964 non-null float64
# 营业收入同比增长率/%    3027 non-null float64
# 利润总额同比增长率/%    3028 non-null float64
# dtypes: float64(8), object(2)
# memory usage: 236.9+ KB

# %%
#总记录条数
len(data.index)
# Out:
# 3031

# %%
#有效记录条数
data_drop = data.dropna(axis=0,how='any')
print(len(data_drop))
# Out:
# 2107

# %%
#计算缺失率
len(data[data['利息保障倍数'].isnull()])/len(data['利息保障倍数'])
# Out:
# 0.2979214780600462

# %%
#计算各字段缺失率
for i in data.columns:
    print(i)
    print(len(data[data[i].isnull()])/len(data)*100)
# Out:
# 证券代码
# 0.0
# 证券简称
# 0.0
# 净资产收益率/%
# 0.5938634114153745
# 总资产报酬率/%
# 1.7485978225008247
# 资产负债率/%
# 0.09897723523589574
# 利息保障倍数
# 29.79214780600462
# 总资产周转率/次
# 0.13196964698119432
# 应收账款周转率/次
# 2.210491586935005
# 营业收入同比增长率/%
# 0.13196964698119432
# 利润总额同比增长率/%
# 0.09897723523589574
