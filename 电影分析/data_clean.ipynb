# %%
import numpy as np
import pandas as pd

# %%
# 1.合并数据(王艺霖)

# 豆瓣数据
data1 = pd.read_csv('./cx.csv')

# 合并艺恩数据
lj1 = pd.read_csv('./lj1.csv') 
lj2 = pd.read_csv('./lj2.csv')
data2 = pd.concat([lj1,lj2])

# 处理艺恩票房数据
data2 = data2.loc[:,data2.columns != '_id']
data2 = data2.loc[:,['MovieName','SumBoxOffice','MovieFxAll','MovieZz']]
data2.columns = ['电影名','票房','发行公司','制片公司']

#合并豆瓣艺恩数据
data = data1.merge(data2,left_on="电影名",right_on="电影名",how="outer")

# %%
data
# Out:
#                                             电影名                    导演  \
# 0                                    周杰伦无与伦比演唱会                   周杰伦
# 1                                 角斗士 Gladiator               雷德利·斯科特
# 2      外出就餐3：饕餮自助 Eating Out 3: All You Can Eat                 葛伦·盖洛
# 3                  蝴蝶效应2 The Butterfly Effect 2             约翰·R·莱昂耐迪
# 4                           铁血柔情 Love Me Tender              罗伯特·D·韦布
# 5                                          王的男妃                    曹毅
# 6                           键盘上的鬣狗 正式版 건반위의하이에나                   郑亨敦
# 7                                  冰川时代 Ice Age              卡洛斯·沙尔丹哈
# 8                                          危情雪夜                   陈国星
# 9             李尔王 Great Performances: King Lear                特雷弗·纳恩
# 10                极限特工2 xXx: State of the Union                李·塔玛霍瑞
# 11                                大逃杀 バトル・ロワイアル                  深作欣二
# 12                                         蜀山奇侠                    萧笙
# 13                              范海辛 Van Helsing               斯蒂芬·索莫斯
# 14                                      三生三世枕上书                    杨玄
# 15                                      芭啦芭啦樱之花                   马楚成
# 16                                        中国有嘻哈                    车澈
# 17                     伟大的寂静 Il grande silenzio              赛尔乔·科尔布奇
# 18             茜茜公主2 Sissi - Die junge Kaiserin              恩斯特·马里施卡
# 19             牧场之家好做伴 A Prairie Home Companion               罗伯特·奥特曼
# 20                           失忆风云 4Got10 (2015)  Timothy Woodward Jr.
# 21                                         非常完美                   金依萌
# 22                                         非常完美                   金依萌
# 23           疯狂的麦克斯3 Mad Max Beyond Thunderdome                 乔治·米勒
# 24                                         我是证人                   安相勋
# 25                                         我是证人                   安相勋
# 26                                      人不彪悍枉少年                    邓科
# 27                           爱上艾略特 Doing Elliot        Noel Alejandro
# 28                                          别这样                   陈健朗
# 29                             救生艇 The Lifeboat               蒂尼斯·艾葛温
# ...                                         ...                   ...
# 21418                               龙日一，你死定了第二季                   NaN
# 21419                                 美丽俏佳人2018                   NaN
# 21420                                 一千零一夜 出走季                   NaN
# 21421                                花落宫廷错流年第二季                   NaN
# 21422                                  食玩天空 第1季                   NaN
# 21423                                  跨界喜剧王第二季                   NaN
# 21424                                   超强音浪第四季                   NaN
# 21425                                     拜见小师父                   NaN
# 21426                               二次元TOP SHOW                   NaN
# 21427                                暴走恐怖故事 第6季                   NaN
# 21428                                      中国情书                   NaN
# 21429                                       枪神记                   NaN
# 21430                                  快乐东西 第4季                   NaN
# 21431                                     出线了初恋                   NaN
# 21432                               迪迪帮帮总动员 第1季                   NaN
# 21433                                    我在未来等你                   NaN
# 21434                           乐高侏罗纪世界：逃走的帝王暴龙                   NaN
# 21435                                    SCI谜案集                   NaN
# 21436                                      暴走家丁                   NaN
# 21437                                  可可小爱 旅游篇                   NaN
# 21438                                  可可小爱 贺岁篇                   NaN
# 21439                                 翼飞冲天之天际战骑                   NaN
# 21440                                   悦时尚2018                   NaN
# 21441                                   吐槽大会第三季                   NaN
# 21442                        岳云鹏相声专场北美巡演纽约站2018                   NaN
# 21443                                      纳米学院                   NaN
# 21444                                红孩儿之趴趴蛙寻石记                   NaN
# 21445                                   阅读阅美第二季                   NaN
# 21446                                 猪猪侠之五灵守卫者                   NaN
# 21447                                  女王进行时第二季                   NaN
#
#                                                    编剧  \
# 0                                              暂无编剧信息
# 1                              大卫·弗兰佐尼,约翰·洛根,威廉姆·尼克尔森
# 2                                    菲利普·J·巴特尔,亚伦·布洛卡
# 3                                    Michael D. Weiss
# 4                                     莫里斯·杰拉蒂,罗伯特·巴克纳
# 5                                                  曹毅
# 6                                              暂无编剧信息
# 7                            迈克尔·伯格 ,迈克尔·J·威尔森,彼得·阿克曼
# 8                                                  郝建
# 9                                                莎士比亚
# 10                                             西蒙·金伯格
# 11                                          深作健太,高见广春
# 12                                    林少枝,钟政良,吴玉章,曾广平
# 13                                            斯蒂芬·索莫斯
# 14                                    梁振华,胡雅婷,黄姗姗,何庆平
# 15                                                陈淑贤
# 16                                                岑俊义
# 17     马里奥·阿门多拉,布鲁诺·科尔布奇,赛尔乔·科尔布奇,Vittoriano Petrilli
# 18                                           恩斯特·马里施卡
# 19                                            加里森·凯勒尔
# 20                                          Sean Ryan
# 21                                                金依萌
# 22                                                金依萌
# 23                                        乔治·米勒,特里·海斯
# 24                                    顾小白,安相勋,尹昌业,崔民硕
# 25                                    顾小白,安相勋,尹昌业,崔民硕
# 26                                                 孙笑
# 27                                     Noel Alejandro
# 28                                        陈健朗,卢佳裕,谭徽扬
# 29                            小威廉·保尔斯,Charlotte Rogan
# ...                                               ...
# 21418                                             NaN
# 21419                                             NaN
# 21420                                             NaN
# 21421                                             NaN
# 21422                                             NaN
# 21423                                             NaN
# 21424                                             NaN
# 21425                                             NaN
# 21426                                             NaN
# 21427                                             NaN
# 21428                                             NaN
# 21429                                             NaN
# 21430                                             NaN
# 21431                                             NaN
# 21432                                             NaN
# 21433                                             NaN
# 21434                                             NaN
# 21435                                             NaN
# 21436                                             NaN
# 21437                                             NaN
# 21438                                             NaN
# 21439                                             NaN
# 21440                                             NaN
# 21441                                             NaN
# 21442                                             NaN
# 21443                                             NaN
# 21444                                             NaN
# 21445                                             NaN
# 21446                                             NaN
# 21447                                             NaN
#
#                                                       演员                 上映时间  \
# 0                                                    周杰伦     2004-10-02(中国台湾)
# 1      罗素·克劳,华金·菲尼克斯,康妮·尼尔森,奥列佛·里德,理查德·哈里斯,德里克·雅各比,杰曼...       2000-05-05(美国)
# 2      利百加·科汉,克里斯·萨尔瓦多,迈克尔E.R.沃克,敏科·斯荳,莱斯利·乔丹,素玛立·蒙塔诺...           2009-10-09
# 3                埃里克·里夫利,埃莉卡·杜兰斯,达斯汀·米利甘,吉娜·赫尔顿,林赛·麦克斯维尔       2006-10-10(美国)
# 4                 Richard Egan,Debra Paget,Elvis Presley           1956-11-15
rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21448 entries, 0 to 21447
# Data columns (total 11 columns):
# 电影名     21448 non-null object
# 导演      7539 non-null object
# 编剧      7539 non-null object
# 演员      7539 non-null object
# 上映时间    7539 non-null object
# 片长      7539 non-null object
# 类型      7539 non-null object
# 评分      7539 non-null object
# 票房      15210 non-null float64
# 发行公司    7600 non-null object
# 制片公司    10428 non-null object
# dtypes: float64(1), object(10)
# memory usage: 2.0+ MB

# %%
# 2.电影名重名处理(闵佳辉)
data.drop_duplicates(subset=['电影名'],inplace=True)

print()

# 查看处理后情况
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17475 entries, 0 to 21447
# Data columns (total 11 columns):
# 电影名     17475 non-null object
# 导演      6885 non-null object
# 编剧      6885 non-null object
# 演员      6885 non-null object
# 上映时间    6885 non-null object
# 片长      6885 non-null object
# 类型      6885 non-null object
# 评分      6885 non-null object
# 票房      11311 non-null float64
# 发行公司    4739 non-null object
# 制片公司    7191 non-null object
# dtypes: float64(1), object(10)
# memory usage: 1.6+ MB

# %%
# 3.电影导演处理(闵佳辉)

#查看导演为空的数据情况
data.dropna(subset=['导演']).info()

#删除导演为空的数据
data.dropna(subset=['导演'],inplace=True)

#删除暂无导演信息的数据
data = data[data['导演'] != '暂无导演信息']

print()

# 查看处理后情况
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6885 entries, 0 to 7538
# Data columns (total 11 columns):
# 电影名     6885 non-null object
# 导演      6885 non-null object
# 编剧      6885 non-null object
# 演员      6885 non-null object
# 上映时间    6885 non-null object
# 片长      6885 non-null object
# 类型      6885 non-null object
# 评分      6885 non-null object
# 票房      721 non-null float64
# 发行公司    515 non-null object
# 制片公司    634 non-null object
# dtypes: float64(1), object(10)
# memory usage: 645.5+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6841 entries, 0 to 7538
# Data columns (total 11 columns):
# 电影名     6841 non-null object
# 导演      6841 non-null object
# 编剧      6841 non-null object
# 演员      6841 non-null object
# 上映时间    6841 non-null object
# 片长      6841 non-null object
# 类型      6841 non-null object
# 评分      6841 non-null object
# 票房      720 non-null float64
# 发行公司    514 non-null object
# 制片公司    633 non-null object
# dtypes: float64(1), object(10)
# memory usage: 641.3+ KB

# %%
# 4.电影编剧处理(游博)

#查看编剧为空的数据情况
data.dropna(subset=['编剧']).info()

#删除编剧为空的数据
data.dropna(subset=['编剧'],inplace=True)

#删除暂无编剧信息的数据
data = data[data['编剧'] != '暂无编剧信息']

print()

# 查看处理后情况
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6841 entries, 0 to 7538
# Data columns (total 11 columns):
# 电影名     6841 non-null object
# 导演      6841 non-null object
# 编剧      6841 non-null object
# 演员      6841 non-null object
# 上映时间    6841 non-null object
# 片长      6841 non-null object
# 类型      6841 non-null object
# 评分      6841 non-null object
# 票房      720 non-null float64
# 发行公司    514 non-null object
# 制片公司    633 non-null object
# dtypes: float64(1), object(10)
# memory usage: 641.3+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6612 entries, 1 to 7538
# Data columns (total 11 columns):
# 电影名     6612 non-null object
# 导演      6612 non-null object
# 编剧      6612 non-null object
# 演员      6612 non-null object
# 上映时间    6612 non-null object
# 片长      6612 non-null object
# 类型      6612 non-null object
# 评分      6612 non-null object
# 票房      717 non-null float64
# 发行公司    514 non-null object
# 制片公司    631 non-null object
# dtypes: float64(1), object(10)
# memory usage: 619.9+ KB
# D:\Anconda\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
# 5.电影演员处理(游博)

#查看演员为空的数据情况(数据匹配度提高，所以删除)
data.dropna(subset=['演员']).info()

#删除演员为空的数据
data.dropna(subset=['演员'],inplace=True)

#删除暂无演员信息的数据
data = data[data['演员'] != '暂无演员信息']

print()

# 查看处理后情况
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6612 entries, 1 to 7538
# Data columns (total 11 columns):
# 电影名     6612 non-null object
# 导演      6612 non-null object
# 编剧      6612 non-null object
# 演员      6612 non-null object
# 上映时间    6612 non-null object
# 片长      6612 non-null object
# 类型      6612 non-null object
# 评分      6612 non-null object
# 票房      717 non-null float64
# 发行公司    514 non-null object
# 制片公司    631 non-null object
# dtypes: float64(1), object(10)
# memory usage: 619.9+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6549 entries, 1 to 7538
# Data columns (total 11 columns):
# 电影名     6549 non-null object
# 导演      6549 non-null object
# 编剧      6549 non-null object
# 演员      6549 non-null object
# 上映时间    6549 non-null object
# 片长      6549 non-null object
# 类型      6549 non-null object
# 评分      6549 non-null object
# 票房      715 non-null float64
# 发行公司    514 non-null object
# 制片公司    631 non-null object
# dtypes: float64(1), object(10)
# memory usage: 614.0+ KB

# %%
# 6.上映时间处理(王艺霖)

# 查看上映时间的数据情况
data.dropna(subset=['上映时间']).info()

# 删除上映时间为空的数据
data.dropna(subset=['上映时间'],inplace=True)

# 删除暂无上映时间的数据
data = data[data['上映时间'] != '暂无上映时间']

# 提取上映时间年份
# (1).将上映时间这列数据取出将ndarray转为list
list_showtime = data.loc[:,'上映时间'].values.tolist()

# (2).取出年份
lists_showtime = []
for list in list_showtime:
    lists_showtime.append(list[:4])
    
# (3).拼接处理后的数据
data_showtime = pd.DataFrame(lists_showtime,index=data.index,columns=['上映时间(年)'])
datas = data.merge(data_showtime,left_on=data.index,right_on=data_showtime.index,how="outer")

# (4).将原上映时间和key_0列删除
columns = datas.columns[(datas.columns!='key_0') & (datas.columns!='上映时间')]
data = datas.loc[:,columns]

print()

# 查看处理后情况
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6549 entries, 1 to 7538
# Data columns (total 11 columns):
# 电影名     6549 non-null object
# 导演      6549 non-null object
# 编剧      6549 non-null object
# 演员      6549 non-null object
# 上映时间    6549 non-null object
# 片长      6549 non-null object
# 类型      6549 non-null object
# 评分      6549 non-null object
# 票房      715 non-null float64
# 发行公司    514 non-null object
# 制片公司    631 non-null object
# dtypes: float64(1), object(10)
# memory usage: 614.0+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6396 entries, 0 to 6395
# Data columns (total 11 columns):
# 电影名        6396 non-null object
# 导演         6396 non-null object
# 编剧         6396 non-null object
# 演员         6396 non-null object
# 片长         6396 non-null object
# 类型         6396 non-null object
# 评分         6396 non-null object
# 票房         710 non-null float64
# 发行公司       512 non-null object
# 制片公司       627 non-null object
# 上映时间(年)    6396 non-null object
# dtypes: float64(1), object(10)
# memory usage: 599.6+ KB

# %%
# 7.电影片长处理(王艺霖)

# 查看片长不存在的数据情况
data[data.loc[:,'片长']!='暂无电影时长'].info()

# 将暂无电影时长数据改为0分钟，但类型为str
data.loc[data[(data['片长']=='暂无电影时长')].index,'片长']='0分钟'

# 将空数据替换为0分钟
data['片长'].fillna('0分钟',inplace=True)

# 用正则表达式处理电影片长只剩数值部分

# (1).将片长这列数据取出将ndarray转为list
list_time = data.loc[:,'片长'].values.tolist()

# (2).正则表达式处理
lists = []
import re
for list in list_time:
    lists.append(re.sub("\D", "", list))

# (3).处理特殊数据    
lists_finally = []
for i in lists:
    if len(i) < 3:
        lists_finally.append(i)
    elif len(i) > 3 and int(i[:2]) < 20:
        lists_finally.append(i[:3])
    elif len(i) > 3 and int(i[:2]) > 20:
        lists_finally.append(i[:2])
    else:
        lists_finally.append(i)

# (4).将0替换为120,因为电影时长一般都为120
lists_end = []
for list in lists_finally:
    if list == str(0):
        lists_end.append(120)
    else:
        lists_end.append(list)
        
# (5).拼接处理后的数据
data_movietime = pd.DataFrame(lists_end,index=data.index,columns=['电影时长(分钟)'])
datas = data.merge(data_movietime,left_on=data.index,right_on=data_movietime.index,how="outer")

# (6).修改电影时长(分钟)的数据类型
datas['电影时长(分钟)'] = datas['电影时长(分钟)'].astype('int')

# (7).将原片长和key_0列删除
columns = datas.columns[(datas.columns!='key_0') & (datas.columns!='片长')]
data = datas.loc[:,columns]

print()

# 查看处理后情况
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4814 entries, 0 to 6393
# Data columns (total 11 columns):
# 电影名        4814 non-null object
# 导演         4814 non-null object
# 编剧         4814 non-null object
# 演员         4814 non-null object
# 片长         4814 non-null object
# 类型         4814 non-null object
# 评分         4814 non-null object
# 票房         521 non-null float64
# 发行公司       466 non-null object
# 制片公司       462 non-null object
# 上映时间(年)    4814 non-null object
# dtypes: float64(1), object(10)
# memory usage: 451.3+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6396 entries, 0 to 6395
# Data columns (total 11 columns):
# 电影名         6396 non-null object
# 导演          6396 non-null object
# 编剧          6396 non-null object
# 演员          6396 non-null object
# 类型          6396 non-null object
# 评分          6396 non-null object
# 票房          710 non-null float64
# 发行公司        512 non-null object
# 制片公司        627 non-null object
# 上映时间(年)     6396 non-null object
# 电影时长(分钟)    6396 non-null int32
# dtypes: float64(1), int32(1), object(9)
# memory usage: 574.6+ KB

# %%
# 8.电影类型处理(张玉英)

# 查看类型为空数据(数据虽然较少，但可以不用删除替换为其他)
data.dropna(subset=['类型']).info()

#将类型为nan替换为其他
data['类型'].fillna('其他',inplace=True)

print()

# 查看处理后情况
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6396 entries, 0 to 6395
# Data columns (total 11 columns):
# 电影名         6396 non-null object
# 导演          6396 non-null object
# 编剧          6396 non-null object
# 演员          6396 non-null object
# 类型          6396 non-null object
# 评分          6396 non-null object
# 票房          710 non-null float64
# 发行公司        512 non-null object
# 制片公司        627 non-null object
# 上映时间(年)     6396 non-null object
# 电影时长(分钟)    6396 non-null int32
# dtypes: float64(1), int32(1), object(9)
# memory usage: 574.6+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6396 entries, 0 to 6395
# Data columns (total 11 columns):
# 电影名         6396 non-null object
# 导演          6396 non-null object
# 编剧          6396 non-null object
# 演员          6396 non-null object
# 类型          6396 non-null object
# 评分          6396 non-null object
# 票房          710 non-null float64
# 发行公司        512 non-null object
# 制片公司        627 non-null object
# 上映时间(年)     6396 non-null object
# 电影时长(分钟)    6396 non-null int32
# dtypes: float64(1), int32(1), object(9)
# memory usage: 574.6+ KB

# %%
# 9. 电影评分处理(闵佳辉)

# 查看暂无电影评分数据(数据较少，可以删除)
data[data.loc[:,'评分']!='暂无电影评分'].info()

# 电影评分数据类型与小数点精确处理
data = data[data.loc[:,'评分']!='暂无电影评分']
data['评分'] = data['评分'].astype('float')
data['评分'] = data['评分'].fillna(data['评分'].mean()).round(1)

print()

# 查看处理后情况
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6141 entries, 0 to 6395
# Data columns (total 11 columns):
# 电影名         6141 non-null object
# 导演          6141 non-null object
# 编剧          6141 non-null object
# 演员          6141 non-null object
# 类型          6141 non-null object
# 评分          6141 non-null object
# 票房          698 non-null float64
# 发行公司        509 non-null object
# 制片公司        618 non-null object
# 上映时间(年)     6141 non-null object
# 电影时长(分钟)    6141 non-null int32
# dtypes: float64(1), int32(1), object(9)
# memory usage: 551.7+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6141 entries, 0 to 6395
# Data columns (total 11 columns):
# 电影名         6141 non-null object
# 导演          6141 non-null object
# 编剧          6141 non-null object
# 演员          6141 non-null object
# 类型          6141 non-null object
# 评分          6141 non-null float64
# 票房          698 non-null float64
# 发行公司        509 non-null object
# 制片公司        618 non-null object
# 上映时间(年)     6141 non-null object
# 电影时长(分钟)    6141 non-null int32
# dtypes: float64(2), int32(1), object(8)
# memory usage: 551.7+ KB

# %%
# 10.电影票房处理(王艺霖)

# 查看票房为空的电影信息(不能删除nan，否则没多少数据了)
data[pd.isnull(data['票房'])].info()

# 将票房的nan替换成票房最小值
data['票房'] = data['票房'].fillna(data['票房'].min())

print()

# 查看处理后情况
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5443 entries, 0 to 6395
# Data columns (total 11 columns):
# 电影名         5443 non-null object
# 导演          5443 non-null object
# 编剧          5443 non-null object
# 演员          5443 non-null object
# 类型          5443 non-null object
# 评分          5443 non-null float64
# 票房          0 non-null float64
# 发行公司        0 non-null object
# 制片公司        0 non-null object
# 上映时间(年)     5443 non-null object
# 电影时长(分钟)    5443 non-null int32
# dtypes: float64(2), int32(1), object(8)
# memory usage: 489.0+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6141 entries, 0 to 6395
# Data columns (total 11 columns):
# 电影名         6141 non-null object
# 导演          6141 non-null object
# 编剧          6141 non-null object
# 演员          6141 non-null object
# 类型          6141 non-null object
# 评分          6141 non-null float64
# 票房          6141 non-null float64
# 发行公司        509 non-null object
# 制片公司        618 non-null object
# 上映时间(年)     6141 non-null object
# 电影时长(分钟)    6141 non-null int32
# dtypes: float64(2), int32(1), object(8)
# memory usage: 551.7+ KB

# %%
# 11.处理发行公司与制片公司(不能删除nan，否则没多少数据了)(张玉英)

# 查看相应公司为空数据
data.dropna(subset=['发行公司','制片公司']).info()

# 将nan值替换为暂无相应公司，也不能删除
data['发行公司'] = data['发行公司'].fillna('暂无发行公司')
data['制片公司'] = data['制片公司'].fillna('暂无制片公司')

print()

# 查看处理后情况
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 463 entries, 12 to 6384
# Data columns (total 11 columns):
# 电影名         463 non-null object
# 导演          463 non-null object
# 编剧          463 non-null object
# 演员          463 non-null object
# 类型          463 non-null object
# 评分          463 non-null float64
# 票房          463 non-null float64
# 发行公司        463 non-null object
# 制片公司        463 non-null object
# 上映时间(年)     463 non-null object
# 电影时长(分钟)    463 non-null int32
# dtypes: float64(2), int32(1), object(8)
# memory usage: 41.6+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6141 entries, 0 to 6395
# Data columns (total 11 columns):
# 电影名         6141 non-null object
# 导演          6141 non-null object
# 编剧          6141 non-null object
# 演员          6141 non-null object
# 类型          6141 non-null object
# 评分          6141 non-null float64
# 票房          6141 non-null float64
# 发行公司        6141 non-null object
# 制片公司        6141 non-null object
# 上映时间(年)     6141 non-null object
# 电影时长(分钟)    6141 non-null int32
# dtypes: float64(2), int32(1), object(8)
# memory usage: 551.7+ KB

# %%
# 12.重新排序index和columns(游博)

# 重新排序行索引
indexs = []
for i in range(len(data)):
    indexs.append(i)
data.index = indexs

# 重新排序列索引
data = data.loc[:,['电影名','导演','编剧','演员','类型','电影时长(分钟)','上映时间(年)','评分','票房','发行公司','制片公司']]

# %%
# 13.导出csv文件(闵佳辉)
data.to_csv("movies.csv",index=None,encoding = "utf-8")
