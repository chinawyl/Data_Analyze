# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.arange(0,10,0.1)
y1=0.05*x**2
y2=-1*y1

# %%
fig,ax1=plt.subplots()
ax2=ax1.twinx()   #产生一个ax1的镜面坐标ax2，ax1与ax2共享一个x轴
ax1.plot(x,y1,'green')
ax2.plot(x,y2,color='blue',linestyle='--')
plt.show()
