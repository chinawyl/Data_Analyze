# %%
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
y_3 = [11,17,16,11,12,11,12,6,6,7,8,9,12,15,14,17,18,21,16,17,20,14,15,15,15,19,21,22,22,22,23]
y_10 = [26,26,28,19,21,17,16,19,18,20,20,19,22,23,17,20,21,20,22,15,11,15,5,13,17,10,11,13,12,13,5]

# %%
x_3 = range(1,32)
x_10 = range(51,82)

# %%
#设置图片大小
plt.figure(figsize=(20,8),dpi=80)

#设置字体
my_font = FontProperties(fname=r"C:\Windows\Fonts\simsun.ttc", size=14)

#绘制图片
plt.scatter(x_3,y_3,label="3月份")
plt.scatter(x_10,y_10,label="10月份")

#设置x轴的刻度
x = list(x_3) + list(x_10)
x_labels = ["3月{}日".format(i) for i in x_3]
x_labels += ["10月{}日".format(i-50) for i in x_10]
plt.xticks(x[::3],x_labels[::3],fontproperties=my_font,rotation=45)

#添加描述信息
plt.xlabel("时间",fontproperties=my_font)
plt.ylabel("温度",fontproperties=my_font)
plt.title("3月和10月温度比较",fontproperties=my_font)

#添加图例
plt.legend(prop=my_font,loc="upper left")

#保存图片
plt.savefig("./Test.png") #保存为.svg格式矢量图，不会有失帧

#展示图片
plt.show()
