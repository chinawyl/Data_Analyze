# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('./data.csv')

# %%
data
# Out:
#      地区  新增确诊   累计确诊     治愈    死亡
# 0    湖北   126  67592  41966  2931
# 1    广东     1   1351   1209     7
# 2    河南     0   1272   1242    22
# 3    浙江     0   1215   1153     1
# 4    湖南     0   1018    952     4
# 5    安徽     0    990    970     6
# 6    江西     0    935    908     1
# 7    山东     0    758    602     6
# 8    江苏     0    631    588     -
# 9    重庆     0    576    513     6
# 10   四川     0    539    428     3
# 11  黑龙江     0    481    380    13
# 12   北京     4    422    298     8
# 13   上海     1    339    306     3
# 14   河北     0    318    305     6
# 15   福建     0    296    278     1
# 16   广西     0    252    217     2
# 17   陕西     0    245    224     1
# 18   云南     0    174    170     2
# 19   海南     0    168    158     6
# 20   贵州     0    146    114     2
# 21   天津     0    136    128     3
# 22   山西     0    133    126     -
# 23   辽宁     0    125    106     1
# 24   香港     0    104     46     2
# 25   甘肃    11    102     87     2
# ...

# %%
#行标签倒序排序
data.sort_index(ascending=False)
# Out:
#      地区  新增确诊   累计确诊     治愈    死亡
# 33   西藏     0      1      1     -
# 32   澳门     0     10      9     -
# 31   青海     0     18     18     -
# 30   台湾     2     44     12     1
# 29  内蒙古     0     75     65     1
# 28   宁夏     0     75     69     -
# 27   新疆     0     76     70     3
# 26   吉林     0     93     89     1
# 25   甘肃    11    102     87     2
# 24   香港     0    104     46     2
# 23   辽宁     0    125    106     1
# 22   山西     0    133    126     -
# 21   天津     0    136    128     3
# 20   贵州     0    146    114     2
# 19   海南     0    168    158     6
# 18   云南     0    174    170     2
# 17   陕西     0    245    224     1
# 16   广西     0    252    217     2
# 15   福建     0    296    278     1
# 14   河北     0    318    305     6
# 13   上海     1    339    306     3
# 12   北京     4    422    298     8
# 11  黑龙江     0    481    380    13
# 10   四川     0    539    428     3
# 9    重庆     0    576    513     6
# 8    江苏     0    631    588     -
# ...

# %%
#按列排序，默认为axis=0
data.sort_index(axis=1)
# Out:
#      地区  新增确诊    死亡     治愈   累计确诊
# 0    湖北   126  2931  41966  67592
# 1    广东     1     7   1209   1351
# 2    河南     0    22   1242   1272
# 3    浙江     0     1   1153   1215
# 4    湖南     0     4    952   1018
# 5    安徽     0     6    970    990
# 6    江西     0     1    908    935
# 7    山东     0     6    602    758
# 8    江苏     0     -    588    631
# 9    重庆     0     6    513    576
# 10   四川     0     3    428    539
# 11  黑龙江     0    13    380    481
# 12   北京     4     8    298    422
# 13   上海     1     3    306    339
# 14   河北     0     6    305    318
# 15   福建     0     1    278    296
# 16   广西     0     2    217    252
# 17   陕西     0     1    224    245
# 18   云南     0     2    170    174
# 19   海南     0     6    158    168
# 20   贵州     0     2    114    146
# 21   天津     0     3    128    136
# 22   山西     0     -    126    133
# 23   辽宁     0     1    106    125
# 24   香港     0     2     46    104
# 25   甘肃    11     2     87    102
# ...

# %%
#按值排序
data.sort_values(by='新增确诊')
# Out:
#      地区  新增确诊   累计确诊     治愈    死亡
# 16   广西     0    252    217     2
# 31   青海     0     18     18     -
# 29  内蒙古     0     75     65     1
# 28   宁夏     0     75     69     -
# 27   新疆     0     76     70     3
# 26   吉林     0     93     89     1
# 24   香港     0    104     46     2
# 23   辽宁     0    125    106     1
# 22   山西     0    133    126     -
# 21   天津     0    136    128     3
# 20   贵州     0    146    114     2
# 19   海南     0    168    158     6
# 18   云南     0    174    170     2
# 17   陕西     0    245    224     1
# 32   澳门     0     10      9     -
# 33   西藏     0      1      1     -
# 14   河北     0    318    305     6
# 2    河南     0   1272   1242    22
# 3    浙江     0   1215   1153     1
# 4    湖南     0   1018    952     4
# 5    安徽     0    990    970     6
# 15   福建     0    296    278     1
# 7    山东     0    758    602     6
# 6    江西     0    935    908     1
# 9    重庆     0    576    513     6
# 10   四川     0    539    428     3
# ...

# %%
data = data.replace('-',0)

# %%
data['死亡'] = data['死亡'].apply(int)

# %%
data
# Out:
#      地区  新增确诊   累计确诊     治愈    死亡
# 0    湖北   126  67592  41966  2931
# 1    广东     1   1351   1209     7
# 2    河南     0   1272   1242    22
# 3    浙江     0   1215   1153     1
# 4    湖南     0   1018    952     4
# 5    安徽     0    990    970     6
# 6    江西     0    935    908     1
# 7    山东     0    758    602     6
# 8    江苏     0    631    588     0
# 9    重庆     0    576    513     6
# 10   四川     0    539    428     3
# 11  黑龙江     0    481    380    13
# 12   北京     4    422    298     8
# 13   上海     1    339    306     3
# 14   河北     0    318    305     6
# 15   福建     0    296    278     1
# 16   广西     0    252    217     2
# 17   陕西     0    245    224     1
# 18   云南     0    174    170     2
# 19   海南     0    168    158     6
# 20   贵州     0    146    114     2
# 21   天津     0    136    128     3
# 22   山西     0    133    126     0
# 23   辽宁     0    125    106     1
# 24   香港     0    104     46     2
# 25   甘肃    11    102     87     2
# ...
