# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_excel('./某公司员工属性.xls')

# %%
data
# Out:
#      离职  年龄    出差   日效率    部门  上班距离  学历    专业  雇佣次数   员工号  ...  人际关系满意度 标准工时  \
# 0     是  41  很少出差  1102    销售     1   2  生物工程     1     1  ...        1   80
# 1     否  49  经常出差   279    研发     8   1  生物工程     1     2  ...        4   80
# 2     是  37  很少出差  1373    研发     2   2    其他     1     4  ...        2   80
# 3     否  33  经常出差  1392    研发     3   4  生物工程     1     5  ...        3   80
# 4     否  27  很少出差   591    研发     2   1    药学     1     7  ...        4   80
# 5     否  32  经常出差  1005    研发     2   2  生物工程     1     8  ...        3   80
# 6     否  59  很少出差  1324    研发     3   3    药学     1    10  ...        1   80
# 7     否  30  很少出差  1358    研发    24   1  生物工程     1    11  ...        2   80
# 8     否  38  经常出差   216    研发    23   3  生物工程     1    12  ...        2   80
# 9     否  36  很少出差  1299    研发    27   3    药学     1    13  ...        2   80
# 10    否  35  很少出差   809    研发    16   3    药学     1    14  ...        3   80
# ...

# %%
data['出差'].unique()
# Out:
# array(['很少出差', '经常出差', '不出差'], dtype=object)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(data['专业'].values.tolist())
data['专业'] = le.transform(data['专业'].values.tolist())

# %%
data
# Out:
#      离职  年龄    出差   日效率    部门  上班距离  学历  专业  雇佣次数   员工号  ...  人际关系满意度 标准工时  \
# 0     是  41  很少出差  1102    销售     1   2   3     1     1  ...        1   80
# 1     否  49  经常出差   279    研发     8   1   3     1     2  ...        4   80
# 2     是  37  很少出差  1373    研发     2   2   1     1     4  ...        2   80
# 3     否  33  经常出差  1392    研发     3   4   3     1     5  ...        3   80
# 4     否  27  很少出差   591    研发     2   1   4     1     7  ...        4   80
# 5     否  32  经常出差  1005    研发     2   2   3     1     8  ...        3   80
# 6     否  59  很少出差  1324    研发     3   3   4     1    10  ...        1   80
# 7     否  30  很少出差  1358    研发    24   1   3     1    11  ...        2   80
# 8     否  38  经常出差   216    研发    23   3   3     1    12  ...        2   80
# 9     否  36  很少出差  1299    研发    27   3   4     1    13  ...        2   80
# 10    否  35  很少出差   809    研发    16   3   4     1    14  ...        3   80
# ...
